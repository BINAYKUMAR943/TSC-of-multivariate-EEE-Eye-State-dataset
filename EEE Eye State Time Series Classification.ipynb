# %%
from scipy.io import arff
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from matplotlib import pyplot as plt
import numpy as np

# %%
data,meta = arff.loadarff('D:/UEA/Kaggle Practice/EEE Eye State/EEG Eye State.arff')
#print(data)
#data[0]--> data[0] contains all the data
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#        AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         P8       T8      FC6       F4       F8      AF4 eyeDetection
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85         b'0'
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10         b'0'
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23         b'0'
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41         b'0'
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46         b'0'

# %%
meta
# Out:
# Dataset: EEG_DATA
# 	AF3's type is numeric
# 	F7's type is numeric
# 	F3's type is numeric
# 	FC5's type is numeric
# 	T7's type is numeric
# 	P7's type is numeric
# 	O1's type is numeric
# 	O2's type is numeric
# 	P8's type is numeric
# 	T8's type is numeric
# 	FC6's type is numeric
# 	F4's type is numeric
# 	F8's type is numeric
# 	AF4's type is numeric
# 	eyeDetection's type is nominal, range is ('0', '1')

# %%
#The Label of the dataset is in byte
type(df.iloc[0,14])
# Out:
# bytes

# %%
y=df['eyeDetection']
X=df.iloc[:,:-1]

# %%
X.shape
# Out:
# (14980, 14)

# %%
#y.shape
y
# Out:
# 0        b'0'
# 1        b'0'
# 2        b'0'
# 3        b'0'
# 4        b'0'
#          ...
# 14975    b'1'
# 14976    b'1'
# 14977    b'1'
# 14978    b'1'
# 14979    b'1'
# Name: eyeDetection, Length: 14980, dtype: object

# %%
X.head()
# Out:
#        AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         P8       T8      FC6       F4       F8      AF4
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46

# %%
y.head()
# Out:
# 0    b'0'
# 1    b'0'
# 2    b'0'
# 3    b'0'
# 4    b'0'
# Name: eyeDetection, dtype: object

# %%
t=np.arange(0,(117*20),117)
first_twenty_records=X.head(20)
plt.plot(t,first_twenty_records['AF3'])

# %%
first_twenty_records
# Out:
#         AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0   4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1   4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2   4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3   4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4   4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
# 5   4321.03  4004.62  4284.10  4153.33  4345.64  4587.18  4093.33  4616.92
# 6   4319.49  4001.03  4280.51  4151.79  4343.59  4584.62  4089.74  4615.90
# 7   4325.64  4006.67  4278.46  4143.08  4344.10  4583.08  4087.18  4614.87
# 8   4326.15  4010.77  4276.41  4139.49  4345.13  4584.10  4091.28  4608.21
# 9   4326.15  4011.28  4276.92  4142.05  4344.10  4582.56  4092.82  4608.72
# 10  4326.15  4010.77  4272.82  4143.08  4342.56  4579.49  4087.69  4615.90
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %%
steps = [
    ("concatenate", ColumnConcatenator()),
    ("classify", TimeSeriesForestClassifier(n_estimators=100)),
]
clf = Pipeline(steps)
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-e2e585f714fd> in <module>
#       4 ]
#       5 clf = Pipeline(steps)
# ----> 6 clf.fit(X_train, y_train)
#       7 clf.score(X_test, y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     339         """
#     340         fit_params_steps = self._check_fit_params(**fit_params)
# --> 341         Xt = self._fit(X, y, **fit_params_steps)
#     342         with _print_elapsed_time('Pipeline',
#     343                                  self._log_message(len(self.steps) - 1)):
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     301                 cloned_transformer = clone(transformer)
#     302             # Fit or load from cache the current transformer
# ...
